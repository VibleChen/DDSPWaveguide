# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
from GuitarString import GuitarString
from Constant import SR
from IPython.display import Audio

# %% [markdown]
# ## Instance the Model

# %%
guitarstring = GuitarString(seconds = 2, trainable = False)

# %% [markdown]
# ## Set some random parameters

# %% [markdown]
# #### The length and pluckposition can be set other value to listen the difference.

# %%
length = 48.2

# %%
pluckposition = 0.54

# %%
seconds = 2
excitation = torch.zeros(seconds * SR)
excitation[0] = 0.5

# %%
audio = guitarstring(length,pluckposition,excitation)

# %%
plt.plot(audio)
plt.show()

# %%
Audio(audio.numpy(),rate=SR)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
